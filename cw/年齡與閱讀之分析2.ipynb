# %%
from tqdm import tqdm_notebook
import pandas as pd

# %%
head=['CRM_ID','name','email','birth','birth1','birth2','age']
f=open(r'C:\Users\wells\OneDrive\Desktop\CRM全客戶.csv',encoding='utf-8')
crm=pd.read_csv(f, error_bad_lines = False,names=head)
# Out:
# C:\Users\wells\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
crm=crm.sort_values(by=['CRM_ID','age','birth','birth1','birth2']).reset_index(drop=True)#排序

crm=crm.drop_duplicates(['CRM_ID','name','email'], keep='first', inplace=False).reset_index(drop=True)
#刪除'CRM_ID','name','email'重複的值

# %%
crm1=crm.drop(['email','birth','birth1','birth2'],axis=1)#刪掉欄位

crm1=crm1.dropna(axis=0,how='any').reset_index(drop=True)#刪除年齡為空值

# %%
def chan_type(aa):
    try:
        bb =int(aa['age'])
        return bb
    except:
        return None

# %%
crm['age'] = crm.apply(chan_type,1)

crm_r = crm[crm['age'].notnull()]
crm_e = crm[crm['age'].isnull()]

crm_r=crm_r.drop(['email','birth','birth1','birth2'],axis=1)

# %%
crm_e = crm_e.drop(['birth'],axis=1)

crm_e1 = crm_e[pd.notnull(crm_e['birth1'])].reset_index(drop=True)
crm_e1 = crm_e1.drop(['birth2','age'],axis=1)

crm_e2 = crm_e[pd.notnull(crm_e['birth2'])].reset_index(drop=True)
crm_e2 = crm_e2.drop(['birth1','age'],axis=1)

def chan_type1(aa):
    try:
        bb =pd.to_datetime(aa['birth1'])
        return bb
    except:
        return None

crm_e1['birth1']=crm_e1.apply(chan_type1,1)

crm_e1[crm_e1['birth1'].isnull()]
# Out:
#         CRM_ID name                   email birth1
# 25798  1779540  周碩彬  shuopin.chou@gmail.com    NaT

# %%
crm_e1 = crm_e1.drop([25798]).reset_index(drop=True)

crm_e2[crm_e2['birth2'].isnull()]

crm_e1['birth1'] = crm_e1['birth1'].dt.year

crm_e1['birth1'] = 2019-crm_e1['birth1']

crm_e1=crm_e1.rename(columns={'birth1':'age'})

# %%
def chan_type2(aa):
    try:
        bb =pd.to_datetime(aa['birth2'])
        return bb
    except:
        return None

crm_e2['birth2']=crm_e2.apply(chan_type2,1)

crm_e2[crm_e2['birth2'].isnull()]
# Out:
#         CRM_ID name                       email birth2
# 4312    726537  吳舒涵  lemontree2266@yahoo.com.tw    NaT
# 16024  1779540  周碩彬      shuopin.chou@gmail.com    NaT

# %%
crm_e2 = crm_e2.drop([4312,16024]).reset_index(drop=True)

crm_e2['birth2'] = crm_e2['birth2'].dt.year

crm_e2['birth2'] = 2019-crm_e2['birth2']

crm_e2=crm_e2.rename(columns={'birth2':'age'})

# %%
crm_ea = pd.concat([crm_e1,crm_e2],ignore_index=True)

crm_ea = crm_ea.drop_duplicates(['CRM_ID','name','email'], keep='first', inplace=False).reset_index(drop=True)

crm_ea = crm_ea.drop(['email'],axis=1)

crm_final=pd.concat([crm_r,crm_ea],ignore_index=True)

def change(aa):
    try:
        bb =int(aa['age'])
        return bb
    except:
        return None

crm_final['age']=crm_final.apply(change,1)

crm_final= crm_final[crm_final['age'].isin([n for n in range(15,86)])].reset_index(drop=True)

crm_1545= crm_final[crm_final['age'].isin([n for n in range(15,45)])].reset_index(drop=True)

crm_4560= crm_final[crm_final['age'].isin([n for n in range(45,61)])].reset_index(drop=True)

crm_6085= crm_final[crm_final['age'].isin([f for f in range(61,86)])].reset_index(drop=True)

crm_1545id=list(set(crm_1545['CRM_ID']))

crm_4560id=list(set(crm_4560['CRM_ID']))

crm_6085id=list(set(crm_6085['CRM_ID']))

# %% [markdown]
# # 閱讀整理

# %%
hea=['act','uid','pid','agent_type','stat_time','CRM_ID']
n=open(r'C:\Users\wells\OneDrive\Desktop\view  20190412-20190714.csv',encoding='utf-8')
view=pd.read_csv(n, error_bad_lines = False,names=hea)
view=view.drop('act',axis=1)

# %%
view1545= view[view['CRM_ID'].isin(crm_1545id)].reset_index(drop=True)

view4560= view[view['CRM_ID'].isin(crm_4560id)].reset_index(drop=True)

view6085= view[view['CRM_ID'].isin(crm_6085id)].reset_index(drop=True)

# %%
print(len(crm_1545id),len(crm_4560id),len(crm_6085id))
# Out:
# 546235 239139 30676

# %%
print(round(len(crm_1545id)/(546235+239139+30676),3),round(len(crm_4560id)/(546235+239139+30676),3),round(len(crm_6085id)/(546235+239139+30676),3))
# Out:
# 0.669 0.293 0.038

# %%
print(len(list(set(view1545['CRM_ID']))),len(list(set(view4560['CRM_ID']))),len(list(set(view6085['CRM_ID']))))
# Out:
# 34605 16372 1684

# %%
print(round(len(list(set(view1545['CRM_ID'])))/(34605+16372+1684),4),round(len(list(set(view4560['CRM_ID'])))/(34605+16372+1684),3),round(len(list(set(view6085['CRM_ID'])))/(34605+16372+1684),3))
# Out:
# 0.6571 0.311 0.032

# %%
mobile=0
desktop=0
for i in view4560['agent_type']:
    if i == 'mobile':
        mobile+=1
    elif i == 'desktop':
        desktop+=1
print(mobile,desktop)
# Out:
# 145800 132793

# %%
mobile=0
desktop=0
for i in view1545['agent_type']:
    if i == 'mobile':
        mobile+=1
    elif i == 'desktop':
        desktop+=1
print(mobile,desktop)
# Out:
# 212191 204503

# %%
mobile=0
desktop=0
for i in view6085['agent_type']:
    if i == 'mobile':
        mobile+=1
    elif i == 'desktop':
        desktop+=1
print(mobile,desktop)
# Out:
# 17051 27628

# %% [markdown]
# # 使用時間分析

# %%
view1545['stat_time']=pd.to_datetime(view1545['stat_time'])

view1545['點']=view1545['stat_time'].dt.hour

view4560['stat_time']=pd.to_datetime(view4560['stat_time'])

view4560['點']=view4560['stat_time'].dt.hour

view6085['stat_time']=pd.to_datetime(view6085['stat_time'])

view6085['點']=view6085['stat_time'].dt.hour

# %%
hour=list(set(view1545['點']))

# %%
hourcount=[]
for i in tqdm_notebook(hour):
    hourcount.append(list(view1545['點']).count(i))
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))

# %%
hourcount1545=pd.DataFrame({'幾點':hour,
                           '觀看次數':hourcount})

# %%
hourcount=[]
for i in tqdm_notebook(hour):
    hourcount.append(list(view4560['點']).count(i))
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))

# %%
hourcount4560=pd.DataFrame({'幾點':hour,
                           '觀看次數':hourcount})

# %%
hourcount=[]
for i in tqdm_notebook(hour):
    hourcount.append(list(view6085['點']).count(i))
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))

# %%
hourcount6085=pd.DataFrame({'幾點':hour,
                           '觀看次數':hourcount})

# %% [markdown]
# # 用手機的時間分析

# %%
view1545m=view1545[view1545['agent_type'].isin(['mobile'])].reset_index(drop=True)

view4560m=view4560[view4560['agent_type'].isin(['mobile'])].reset_index(drop=True)

view6085m=view6085[view6085['agent_type'].isin(['mobile'])].reset_index(drop=True)

# %%
view1545m['stat_time']=pd.to_datetime(view1545m['stat_time'])

view1545m['點']=view1545m['stat_time'].dt.hour

view4560m['stat_time']=pd.to_datetime(view4560m['stat_time'])

view4560m['點']=view4560m['stat_time'].dt.hour

view6085m['stat_time']=pd.to_datetime(view6085m['stat_time'])

view6085m['點']=view6085m['stat_time'].dt.hour

# %%
hourcount=[]
for i in tqdm_notebook(hour):
    hourcount.append(list(view1545m['點']).count(i))
    
hourcount1545m=pd.DataFrame({'幾點':hour,
                           '觀看次數':hourcount})
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))

# %%
hourcount=[]
for i in tqdm_notebook(hour):
    hourcount.append(list(view4560m['點']).count(i))
    
hourcount4560m=pd.DataFrame({'幾點':hour,
                           '觀看次數':hourcount})
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))

# %%
hourcount=[]
for i in tqdm_notebook(hour):
    hourcount.append(list(view6085m['點']).count(i))
    
hourcount6085m=pd.DataFrame({'幾點':hour,
                           '觀看次數':hourcount})
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))

# %% [markdown]
# # 用桌機的時間分析

# %%
view1545d=view1545[view1545['agent_type'].isin(['desktop'])].reset_index(drop=True)

view4560d=view4560[view4560['agent_type'].isin(['desktop'])].reset_index(drop=True)

view6085d=view6085[view6085['agent_type'].isin(['desktop'])].reset_index(drop=True)

# %%
view1545d['stat_time']=pd.to_datetime(view1545d['stat_time'])

view1545d['點']=view1545d['stat_time'].dt.hour

view4560d['stat_time']=pd.to_datetime(view4560d['stat_time'])

view4560d['點']=view4560d['stat_time'].dt.hour

view6085d['stat_time']=pd.to_datetime(view6085d['stat_time'])

view6085d['點']=view6085d['stat_time'].dt.hour

# %%
hourcount=[]
for i in tqdm_notebook(hour):
    hourcount.append(list(view1545d['點']).count(i))
    
hourcount1545d=pd.DataFrame({'幾點':hour,
                           '觀看次數':hourcount})
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))

# %%
hourcount=[]
for i in tqdm_notebook(hour):
    hourcount.append(list(view4560d['點']).count(i))
    
hourcount4560d=pd.DataFrame({'幾點':hour,
                           '觀看次數':hourcount})
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))

# %%
hourcount=[]
for i in tqdm_notebook(hour):
    hourcount.append(list(view6085d['點']).count(i))
    
hourcount6085d=pd.DataFrame({'幾點':hour,
                           '觀看次數':hourcount})
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))

# %% [markdown]
# # 文章種類整理

# %%
e=open(r'C:\Users\wells\OneDrive\Desktop\cw-article.csv',encoding='utf8')
cat=pd.read_csv(e, error_bad_lines = False)
cat1=cat.drop(['response_editor','articleAuthors','authors','paywall','onlineTime','type'],axis=1)

# %%
set(cat['masterChannelTitle'])
# Out:
# {'@想像未來',
#  '互動圖表',
#  '人物觀點',
#  '健康關係',
#  '國際',
#  '專欄',
#  '政治社會',
#  '教育',
#  '數據圖表',
#  '時尚生活',
#  '環境',
#  '產業',
#  '經濟學人',
#  '經營管理',
#  '聽天下',
#  '觀點',
#  '調查',
#  '財經時事'}

# %%
cat=cat[cat['masterChannelTitle'].isin(['專欄','觀點','人物觀點','健康關係','國際','政治社會','教育','數據圖表','時尚生活','環境','產業','經濟學人','經營管理','調查','財經時事'])].reset_index(drop=True)
cat=cat.drop(['response_editor','articleAuthors','authors','paywall','onlineTime','type'],axis=1)
cat=cat.drop_duplicates(keep='first',inplace=False).reset_index(drop=True)

cat1=cat1[cat1['masterChannelTitle'].isin(['專欄','觀點','人物觀點','健康關係','國際','政治社會','教育','數據圖表','時尚生活','環境','產業','經濟學人','經營管理','調查','財經時事'])].reset_index(drop=True)

# %%
cathealth=cat1[cat1['masterChannelTitle'].isin(['健康關係'])].reset_index(drop=True)

catpolitics=cat1[cat1['masterChannelTitle'].isin(['政治社會'])].reset_index(drop=True)

cateducation=cat1[cat1['masterChannelTitle'].isin(['教育'])].reset_index(drop=True)

catindustry=cat1[cat1['masterChannelTitle'].isin(['產業'])].reset_index(drop=True)

# %% [markdown]
# # 類別次數字典1(主頻道分類)

# %%
cato_all=[]
for i in tqdm_notebook(cat1['masterChannelTitle']):
    cato_all.append(i)

cato_count=[]
cato_alls=list(set(cato_all))
for i in tqdm_notebook(cato_alls):
    cato_count.append(cato_all.count(i))

c_count1=dict(zip(cato_alls,cato_count))
# Out:
# HBox(children=(IntProgress(value=0, max=56131), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=15), HTML(value='')))

# %%
cato_all=[]
for i in tqdm_notebook(cat1['subChannelTitle']):
    cato_all.append(i)
cato_count=[]
cato_alls=list(set(cato_all))
for i in tqdm_notebook(cato_alls):
    cato_count.append(cato_all.count(i))

sub_count1=dict(zip(cato_alls,cato_count))
# Out:
# HBox(children=(IntProgress(value=0, max=56131), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=115), HTML(value='')))

# %% [markdown]
# # 主頻道分析

# %%
def abc1(aa):
    caty=[]
    for i in tqdm_notebook(aa['pid']):
        try:
            caty.append(cat1[cat1['id'].isin([str(i)])].reset_index(drop=True)['masterChannelTitle'][0])
        except:
            1
    cat_count=[]
    caty_all=list(set(caty))
    for i in tqdm_notebook(caty_all):
        cat_count.append(caty.count(i))
    county=pd.DataFrame({'word':caty_all,
                        'count':cat_count})
    county=county.sort_values(by=['count'],ascending=False).reset_index(drop=True)
    aaa=[]
    for i in tqdm_notebook(range(len(county['count']))):
        aaa.append(county['count'][i]/c_count1[county['word'][i]])
    county['平均點擊']=aaa
    return county

# %%
count45601=abc1(view4560)
# Out:
# HBox(children=(IntProgress(value=0, max=278602), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=15), HTML(value='')))

# %%
count45601.sort_values(by=['平均點擊'],ascending=False).reset_index(drop=True)
# Out:
#     word  count       平均點擊
# 0     觀點  36044  47.614267
# 1   健康關係  41342   9.056298
# 2   政治社會  19140   9.015544
# 3     教育  13509   6.151639
# 4     產業  36317   5.554757
# 5   時尚生活  21097   4.922305
# 6     專欄  14979   4.653308
# 7   人物觀點  13142   4.617709
# 8     調查   3725   4.079956
# 9   經營管理  22477   3.549187
# 10    國際  25167   3.228194
# 11  財經時事  20801   3.126090
# 12  數據圖表   1140   3.040000
# 13    環境   3972   1.480984
# 14  經濟學人   5582   1.151403

# %%
count15851=abc1(view1585)

# %%
count15851.sort_values(by=['平均點擊'],ascending=False).reset_index(drop=True)

# %%
count45601.to_csv(r'C:\Users\wellslu\Desktop\4560.csv',encoding='utf_8_sig')

# %% [markdown]
# # 文章關鍵字整理

# %%
keyword=[]
for i in cat['keyword']:
    keyword.append(str(i).split(','))

# %%
cat['關鍵字']=keyword

# %%
cat=cat.drop(['masterChannelTitle','subChannelTitle'],axis=1).reset_index(drop=True)

# %%
cat=cat.dropna(axis=0,how='any').reset_index(drop=True)

# %%
allkeyword=[]
for i in tqdm_notebook(range(len(cat))):
    allkeyword=allkeyword+cat['keyword'][i].split(',')

# %%
perkeyword=list(set(allkeyword))
countkeyword=[]
for i in tqdm_notebook(perkeyword):
    countkeyword.append(allkeyword.count(i))

# %%
keywordcount=pd.DataFrame({'word':perkeyword,
                          'count':countkeyword})

# %%
del countkeyword[0]
sum(countkeyword)/len(list(countkeyword))

# %%
dickeywordcount=dict(zip(list(perkeyword),countkeyword))
del dickeywordcount['']

# %%
dickeywordcount1={}
for k in dickeywordcount:
    if dickeywordcount[k] >= 5:
        dickeywordcount1[k] = dickeywordcount[k]

# %% [markdown]
# # 主要類別的關鍵字分析(政治)

# %%
viewpolitics1585=view1585[view1585['pid'].isin(catpolitics['id'])].reset_index(drop=True)
viewpolitics4560=view4560[view4560['pid'].isin(catpolitics['id'])].reset_index(drop=True)

# %%
def abc3(aa):
    alllist=[]
    for i in tqdm_notebook(range(len(aa))):
        try:
            alllist=alllist+catpolitics[catpolitics['id'].isin([aa['pid'][i]])].reset_index()['keyword'][0].split(',')
        except:
            1
    setalllist=list(set(alllist))
    countsetalllist=[]
    for i in tqdm_notebook(setalllist):
        countsetalllist.append(alllist.count(i))
    bb=pd.DataFrame({'word':setalllist,
                    'count':countsetalllist})
    return bb

# %%
politicskeywordcount1585=abc3(viewpolitics1585)
# Out:
# HBox(children=(IntProgress(value=0, max=33375), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2094), HTML(value='')))

# %%
politicskeywordcount4560=abc3(viewpolitics4560)
# Out:
# HBox(children=(IntProgress(value=0, max=19989), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1555), HTML(value='')))

# %%
def cc(aa):
    try:
        bb=aa['count']/dickeywordcount1[aa['word']]
        return bb
    except:
        return None
politicskeywordcount4560['平均點擊']=politicskeywordcount4560.apply(cc,axis=1)
politicskeywordcount1585['平均點擊']=politicskeywordcount1585.apply(cc,axis=1)

# %%
politicskeywordcount4560=politicskeywordcount4560.dropna(axis=0,how='any').reset_index(drop=True)

# %%
politicskeywordcount1585=politicskeywordcount1585.dropna(axis=0,how='any').reset_index(drop=True)

# %%
politicskeywordcount1585.sort_values(by='平均點擊',ascending=False).reset_index(drop=True)
# Out:
#              word  count        平均點擊
# 0              網軍   3554  710.800000
# 1            2020   2678  535.600000
# 2            長榮航空   2127  425.400000
# 3              輿論   2732  273.200000
# 4             朱立倫   1292  129.200000
# 5            台灣經濟    541  108.200000
# 6             假資訊    723  103.285714
# 7             國民黨   7177   73.234694
# 8              媽祖    358   71.600000
# 9              統一    535   66.875000
# 10          OMICS    317   63.400000
# 11          韓國瑜造勢    416   52.000000
# 12            媒體戰    535   48.636364
# 13            劉揚偉    238   47.600000
# 14            李伯璋    269   44.833333
# 15             同志    475   43.181818
# 16             路跑    209   41.800000
# 17           一國兩制    202   40.400000
# 18            立法院    313   34.777778
# 19             屏東    190   27.142857
# 20            詹喬愉    159   26.500000
# 21            計程車    313   26.083333
# 22             建築    149   24.833333
# 23           勞資關係    173   24.714286
# 24           閩東文化    109   21.800000
# 25            交通部    215   21.500000
# 26           社群操作    446   20.272727
# 27            王美花    121   20.166667
# 28             伴侶    221   20.090909
# 29           文化經濟     96   19.200000
# ..            ...    ...         ...
# 235          川蔡電話      1    0.076923
# 236   Greg Abbott      1    0.076923
# 237            菊姐      3    0.075000
# 238          國語教會      2    0.071429
# 239            鐵道      1    0.071429
# 240            走私      1    0.071429
# 241         薪資平均數      3    0.066667
# 242         高齡化社會      1    0.062500
# 243            光華      2    0.062500
# 244      港澳台居民居住證      4    0.062500
# 245            關門      4    0.060606
# 246            紫爆      1    0.052632
# 247         嬰兒潮世代      1    0.050000
# 248           博士生      1    0.050000
# 249          精神病患      1    0.047619
# 250            文化      3    0.046875
# 251          國家治理      1    0.041667
# 252           報導者      1    0.037037
# 253           蔡美兒      1    0.033333
# 254          就業趨勢      1    0.031250
# 255            民代      1    0.029412
# 256           囤房稅      1    0.027027
# 257          介護離職      1    0.025641
# 258           天安門      1    0.020408
# 259            台大      1    0.016949
# 260           通膨率      1    0.015625
# 261           燒燙傷      1    0.015152
# 262         文化局局長      1    0.012346
# 263            東協      1    0.010204
# 264           崔順實      1    0.003448
#
# [265 rows x 3 columns]

# %%
politicskeywordcount4560.sort_values(by='平均點擊',ascending=False).reset_index(drop=True)
# Out:
#          word  count        平均點擊
# 0          網軍   1910  382.000000
# 1        2020   1661  332.200000
# 2        長榮航空   1406  281.200000
# 3          輿論   1473  147.300000
# 4         朱立倫    792   79.200000
# 5         假資訊    404   57.714286
# 6        台灣經濟    283   56.600000
# 7       韓國瑜造勢    413   51.625000
# 8       OMICS    237   47.400000
# 9          媽祖    234   46.800000
# 10         統一    369   46.125000
# 11        國民黨   4514   46.061224
# 12         路跑    205   41.000000
# 13        媒體戰    369   33.545455
# 14        李伯璋    197   32.833333
# 15        劉揚偉    128   25.600000
# 16        詹喬愉    130   21.666667
# 17       閩東文化    108   21.600000
# 18        立法院    185   20.555556
# 19       一國兩制     98   19.600000
# 20         同志    205   18.636364
# 21       勞資關係    124   17.714286
# 22       文化經濟     83   16.600000
# 23         屏東    112   16.000000
# 24        交通部    156   15.600000
# 25     A-Team     77   15.400000
# 26        40歲    115   14.375000
# 27         建築     84   14.000000
# 28        劉金標     77   12.833333
# 29         影劇     83   11.857143
# ..        ...    ...         ...
# 163       蔣萬安      1    0.142857
# 164      兆豐產險      1    0.125000
# 165       新鮮人      1    0.125000
# 166       二甲苯      1    0.125000
# 167        光華      4    0.125000
# 168        壓力      2    0.111111
# 169        匯豐      1    0.111111
# 170       陳金德      2    0.105263
# 171       禽流感      1    0.100000
# 172       謝龍介      2    0.100000
# 173      旅遊景點      1    0.090909
# 174      漁船越界      1    0.090909
# 175        世界      1    0.090909
# 176      米崙斷層      1    0.083333
# 177        張派      1    0.083333
# 178        余天      1    0.076923
# 179      新聞媒體      8    0.075472
# 180      進步力量      1    0.071429
# 181      藍綠政黨      5    0.066667
# 182     票務透明化      1    0.066667
# 183        轉型      4    0.060606
# 184        賭場      1    0.055556
# 185       次文化      1    0.055556
# 186      醫師工時      1    0.050000
# 187        文化      3    0.046875
# 188      國語教會      1    0.035714
# 189  港澳台居民居住證      2    0.031250
# 190      司法改革      1    0.028571
# 191      公民討論      1    0.020000
# 192        東協      1    0.010204
#
# [193 rows x 3 columns]

# %% [markdown]
# # 主要類別的關鍵字分析(健康)

# %%
viewhealth1585=view1585[view1585['pid'].isin(cathealth['id'])].reset_index(drop=True)
viewhealth4560=view4560[view4560['pid'].isin(cathealth['id'])].reset_index(drop=True)

# %%
def abc3(aa):
    alllist=[]
    for i in tqdm_notebook(range(len(aa))):
        try:
            alllist=alllist+cathealth[cathealth['id'].isin([aa['pid'][i]])].reset_index()['keyword'][0].split(',')
        except:
            1
    setalllist=list(set(alllist))
    countsetalllist=[]
    for i in tqdm_notebook(setalllist):
        countsetalllist.append(alllist.count(i))
    bb=pd.DataFrame({'word':setalllist,
                    'count':countsetalllist})
    return bb

# %%
healthkeywordcount1585=abc3(viewhealth1585)
# Out:
# HBox(children=(IntProgress(value=0, max=71810), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=3731), HTML(value='')))

# %%
healthkeywordcount4560=abc3(viewhealth4560)
# Out:
# HBox(children=(IntProgress(value=0, max=41403), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2873), HTML(value='')))

# %%
healthkeywordcount4560['平均點擊']=healthkeywordcount4560.apply(cc,axis=1)
healthkeywordcount1585['平均點擊']=healthkeywordcount1585.apply(cc,axis=1)

# %%
healthkeywordcount4560=healthkeywordcount4560.dropna(axis=0,how='any').reset_index(drop=True)

# %%
healthkeywordcount1585=healthkeywordcount1585.dropna(axis=0,how='any').reset_index(drop=True)

# %%
healthkeywordcount1585.sort_values(by='平均點擊',ascending=False).reset_index(drop=True)
# Out:
#               word  count        平均點擊
# 0               長照   3470  694.000000
# 1               減重   1950  325.000000
# 2             第三人生   1494  298.800000
# 3               情緒   2891  289.100000
# 4              巴菲特    893  178.600000
# 5               壓力   2966  164.777778
# 6               血管    603  120.600000
# 7               流汗   1072  119.111111
# 8               戒糖   1715  107.187500
# 9              呼吸道    534  106.800000
# 10             李伯璋    608  101.333333
# 11              伴侶   1398   93.200000
# 12           台大登山社    644   92.000000
# 13            心理素質    447   89.400000
# 14              調查    533   88.833333
# 15              大腦    711   79.000000
# 16              醫美    499   71.285714
# 17              眼球    603   67.000000
# 18            靈魂伴侶    373   62.166667
# 19             40歲    468   58.500000
# 20              感冒   1083   57.000000
# 21              疲勞    311   51.833333
# 22             貝佐斯    442   49.111111
# 23              母乳    292   48.666667
# 24            護理人員    330   47.142857
# 25             早餐人    494   44.909091
# 26              媽祖    214   42.800000
# 27            含糖飲料    420   42.000000
# 28         親愛的彼得先生    205   41.000000
# 29              誠實    323   35.888889
# ..             ...    ...         ...
# 460             實習      1    0.045455
# 461        長期照顧服務法      1    0.045455
# 462           空氣品質      1    0.043478
# 463            兄弟情      1    0.043478
# 464           在地樂活      2    0.041667
# 465          免疫力疾病      1    0.041667
# 466             呼吸      1    0.038462
# 467           器官老化      1    0.037037
# 468             名廚      1    0.035714
# 469             台大      2    0.033898
# 470            壓力衣      2    0.031746
# 471             文化      2    0.031250
# 472           聲帶發炎      4    0.028777
# 473           家庭主婦      1    0.027778
# 474             偷窺      1    0.026316
# 475             機率      1    0.025000
# 476             傷口      1    0.022727
# 477   手指屈指肌腱狹窄性腱鞘炎      1    0.022222
# 478             品格      3    0.019231
# 479            退休金      1    0.018868
# 480          壓力荷爾蒙      1    0.016129
# 481           藏傳佛教      1    0.014925
# 482             談話      2    0.012346
# 483             東協      1    0.010204
# 484          世界展望會      1    0.009091
# 485           智慧藥丸      1    0.007692
# 486              電      1    0.007634
# 487             黃豆      1    0.004717
# 488           病人自主      2    0.004608
# 489             牧場      1    0.002445
#
# [490 rows x 3 columns]

# %%
healthkeywordcount4560.sort_values(by='平均點擊',ascending=False).reset_index(drop=True)
# Out:
#               word  count        平均點擊
# 0               長照   3076  615.200000
# 1             第三人生   1396  279.200000
# 2               減重   1359  226.500000
# 3               情緒   1737  173.700000
# 4              巴菲特    501  100.200000
# 5            台大登山社    595   85.000000
# 6               壓力   1501   83.388889
# 7              李伯璋    456   76.000000
# 8               流汗    653   72.555556
# 9              呼吸道    347   69.400000
# 10              血管    340   68.000000
# 11              戒糖    729   45.562500
# 12              醫美    305   43.571429
# 13              伴侶    606   40.400000
# 14              大腦    347   38.555556
# 15              眼球    340   37.777778
# 16              調查    222   37.000000
# 17             早餐人    394   35.818182
# 18            心理素質    175   35.000000
# 19             40歲    250   31.250000
# 20             貝佐斯    279   31.000000
# 21              媽祖    153   30.600000
# 22            靈魂伴侶    182   30.333333
# 23            全食療法    138   27.600000
# 24            成人教育    137   27.400000
# 25              代謝    386   25.733333
# 26              感冒    448   23.578947
# 27            含糖飲料    234   23.400000
# 28              路跑    115   23.000000
# 29              禪修    113   22.600000
# ..             ...    ...         ...
# 335             松下      1    0.052632
# 336             水痘      1    0.052632
# 337            年輕化      1    0.052632
# 338             年假      1    0.050000
# 339           腸胃蠕動      2    0.050000
# 340           醫師工時      1    0.050000
# 341             物化      1    0.047619
# 342            莊淳鈞      2    0.046512
# 343           人工智慧      1    0.045455
# 344          因為留不住      1    0.045455
# 345   手指屈指肌腱狹窄性腱鞘炎      2    0.044444
# 346           3C成癮      3    0.040000
# 347            憂鬱症      5    0.038760
# 348             科技      3    0.037500
# 349             台大      2    0.033898
# 350            貓頭鷹      1    0.033333
# 351           整理魔法      7    0.030837
# 352              鈣      1    0.030303
# 353            領導課      1    0.027778
# 354            三手菸      1    0.027778
# 355           致癌風險      1    0.026316
# 356             偏見      1    0.026316
# 357             解夢      1    0.023810
# 358             奮鬥      1    0.023256
# 359          壓力荷爾蒙      1    0.016129
# 360            孫逸仙      1    0.015385
# 361           智慧藥丸      2    0.015385
# 362             優惠      1    0.012658
# 363              電      1    0.007634
# 364             聆聽      1    0.002747
#
# [365 rows x 3 columns]

# %% [markdown]
# # 主要類別的關鍵字分析(教育)

# %%
vieweducation1585=view1585[view1585['pid'].isin(cateducation['id'])].reset_index(drop=True)
vieweducation4560=view4560[view4560['pid'].isin(cateducation['id'])].reset_index(drop=True)

# %%
def abc3(aa):
    alllist=[]
    for i in tqdm_notebook(range(len(aa))):
        try:
            alllist=alllist+cateducation[cateducation['id'].isin([aa['pid'][i]])].reset_index()['keyword'][0].split(',')
        except:
            1
    setalllist=list(set(alllist))
    countsetalllist=[]
    for i in tqdm_notebook(setalllist):
        countsetalllist.append(alllist.count(i))
    bb=pd.DataFrame({'word':setalllist,
                    'count':countsetalllist})
    return bb

# %%
educationkeywordcount1585=abc3(vieweducation1585)
# Out:
# HBox(children=(IntProgress(value=0, max=24522), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2367), HTML(value='')))

# %%
educationkeywordcount4560=abc3(vieweducation4560)
# Out:
# HBox(children=(IntProgress(value=0, max=15871), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1718), HTML(value='')))

# %%
educationkeywordcount4560['平均點擊']=educationkeywordcount4560.apply(cc,axis=1)
educationkeywordcount1585['平均點擊']=educationkeywordcount1585.apply(cc,axis=1)

# %%
educationkeywordcount4560=educationkeywordcount4560.dropna(axis=0,how='any').reset_index(drop=True)

# %%
educationkeywordcount1585=educationkeywordcount1585.dropna(axis=0,how='any').reset_index(drop=True)

# %%
educationkeywordcount1585.sort_values(by='平均點擊',ascending=False).reset_index(drop=True)
# Out:
#             word  count        平均點擊
# 0           實驗教育    975  195.000000
# 1           新竹高中   1227  175.285714
# 2             調查    572   95.333333
# 3             程式   1685   88.684211
# 4           親子關係    685   68.500000
# 5          OMICS    317   63.400000
# 6             成大    304   60.800000
# 7            李昭賢    304   38.000000
# 8             文學    188   31.333333
# 9     coding 365    304   27.636364
# 10          翻轉教室    193   27.571429
# 11            企管    268   26.800000
# 12           黃聲遠    133   26.600000
# 13            嬰兒    109   21.800000
# 14            教改    723   20.083333
# 15           蘇慧貞    151   18.875000
# 16          中國留學    103   17.166667
# 17          嘉義高中   1227   13.786517
# 18           博士生    272   13.600000
# 19            個性    148   13.454545
# 20           吳曉樂     67   13.400000
# 21      台灣六大設計名校     78   13.000000
# 22           假資訊     80   11.428571
# 23          能力培養    100   11.111111
# 24           成就感     74   10.571429
# 25           常春藤     95   10.555556
# 26            手遊     63   10.500000
# 27      國際閱讀教育論壇     80   10.000000
# 28          春雨計畫     79    9.875000
# 29         高功能自閉    102    9.272727
# ..           ...    ...         ...
# 261       Pinkoi      1    0.047619
# 262           師生      3    0.044776
# 263          游文聰      3    0.044118
# 264          林昶佐      1    0.043478
# 265         台灣文學      1    0.041667
# 266         經濟法則      1    0.040000
# 267           韓裔      2    0.039216
# 268         科技教學      1    0.034483
# 269       英語畢業門檻      5    0.033784
# 270         生物社群      1    0.033333
# 271         親子共讀      1    0.033333
# 272           旅遊      9    0.033088
# 273           徐薇      4    0.032258
# 274         交易成本      1    0.032258
# 275         公眾場所      1    0.028571
# 276      海內外企業實習      1    0.025641
# 277           印度      1    0.025000
# 278           亂入      1    0.022727
# 279          詹俊宥      3    0.022388
# 280         新聞媒體      2    0.018868
# 281         閱讀素養      1    0.015625
# 282         電腦工程      1    0.015625
# 283           同儕      1    0.014706
# 284          生物課      1    0.010989
# 285         國際學校      1    0.010753
# 286  職場目標從五年規劃開始      1    0.010417
# 287           腦癌      1    0.008065
# 288         外語能力      1    0.003460
# 289        學習共同體      1    0.001957
# 290         黑貓基地      1    0.001109
#
# [291 rows x 3 columns]

# %%
educationkeywordcount4560.sort_values(by='平均點擊',ascending=False).reset_index(drop=True)
# Out:
#             word  count        平均點擊
# 0           新竹高中    810  115.714286
# 1           實驗教育    501  100.200000
# 2             程式   1182   62.210526
# 3             調查    368   61.333333
# 4          OMICS    237   47.400000
# 5             成大    236   47.200000
# 6           親子關係    414   41.400000
# 7            李昭賢    236   29.500000
# 8           翻轉教室    180   25.714286
# 9     coding 365    236   21.454545
# 10            文學    110   18.333333
# 11            企管    142   14.200000
# 12            教改    491   13.638889
# 13           蘇慧貞    105   13.125000
# 14      台灣六大設計名校     78   13.000000
# 15           黃聲遠     61   12.200000
# 16          中國留學     72   12.000000
# 17            手遊     65   10.833333
# 18            嬰兒     54   10.800000
# 19          嘉義高中    810    9.101124
# 20           常春藤     78    8.666667
# 21          能力培養     77    8.555556
# 22            國文     41    8.200000
# 23           博士生    163    8.150000
# 24           假資訊     54    7.714286
# 25      國際閱讀教育論壇     55    6.875000
# 26          春雨計畫     53    6.625000
# 27           謝智翔     64    6.400000
# 28           吳曉樂     31    6.200000
# 29           跨領域     31    6.200000
# ..           ...    ...         ...
# 185   《Google模式》      1    0.076923
# 186          年輕人      1    0.071429
# 187           測驗      1    0.071429
# 188         教學創新      1    0.066667
# 189           文化      4    0.062500
# 190         問題家庭      1    0.058824
# 191      逢甲大學建築系      1    0.055556
# 192       免費線上課程      2    0.054054
# 193     卓蘭農產興業計畫      1    0.050000
# 194           智力      2    0.043478
# 195         台灣文學      1    0.041667
# 196          謝慧游      5    0.039062
# 197        瑪吉斯學程      1    0.038462
# 198         金山高中      1    0.038462
# 199           台大      2    0.033898
# 200         生物社群      1    0.033333
# 201         教學方式      1    0.032258
# 202         因材施教      1    0.032258
# 203       教學卓越計劃      1    0.027778
# 204      海內外企業實習      1    0.025641
# 205         校車測驗      1    0.023256
# 206      新加坡管理學院      1    0.021277
# 207       英語畢業門檻      3    0.020270
# 208         正新輪胎      1    0.019608
# 209           韓裔      1    0.019608
# 210         女性力量      1    0.012987
# 211          生物課      1    0.010989
# 212          詹俊宥      1    0.007463
# 213           旅遊      1    0.003676
# 214        學習共同體      1    0.001957
#
# [215 rows x 3 columns]

# %%
educationkeywordcount4560.to_csv('教育4560.csv',encoding='utf_8_sig')

# %% [markdown]
# # 以個別文章分析

# %%
aa=view.groupby(['pid'],as_index=False)['pid'].agg({'cnt':'count'})

aa=aa.where(aa['cnt']>500)
aa=aa.dropna(axis=0,how='any').reset_index(drop=True)

pid=[]
for i in range(len(aa)):
    pid.append(int(aa['pid'][i]))

# %%
viewpid=[]
for i in tqdm_notebook(pid):
    viewpid.append(list(view1545['pid']).count(i))
# Out:
# HBox(children=(IntProgress(value=0, max=879), HTML(value='')))

# %%
viewpid4560=[]
for i in tqdm_notebook(pid):
    viewpid4560.append(list(view4560['pid']).count(i))
# Out:
# HBox(children=(IntProgress(value=0, max=879), HTML(value='')))

# %%
viewpid6085=[]
for i in tqdm_notebook(pid):
    viewpid6085.append(list(view6085['pid']).count(i))
# Out:
# HBox(children=(IntProgress(value=0, max=879), HTML(value='')))

# %%
artview=pd.DataFrame({'pid':pid,
                     '15~45':viewpid,
                     '45~60':viewpid4560,
                     '60~85':viewpid6085})

# %%
artview['總瀏覽數']=artview['15~45']+artview['45~60']+artview['60~85']

# %%
artview=artview.where(artview['總瀏覽數']>500).dropna(axis=0,how='any').reset_index(drop=True)

# %%
artview['45~60比例']=artview['45~60']/artview['總瀏覽數']

# %%
artview=artview.sort_values(by='45~60比例',ascending=False).reset_index(drop=True)
artview['pid']=artview['pid'].astype('int')

# %%
artviewtitle=[]
for i in tqdm_notebook(list(artview['pid'])):
    try:
        artviewtitle.append(cat[cat['id'].isin([i])].reset_index()['title'][0])
    except:
        artviewtitle.append(None)
# Out:
# HBox(children=(IntProgress(value=0, max=348), HTML(value='')))

# %%
artview['title']=artviewtitle

# %%
artviewmaster=[]
for i in tqdm_notebook(list(artview['pid'])):
    try:
        artviewmaster.append(cat[cat['id'].isin([i])].reset_index()['masterChannelTitle'][0])
    except:
        artviewmaster.append(None)
artview['masterChannelTitle']=artviewmaster
# Out:
# HBox(children=(IntProgress(value=0, max=348), HTML(value='')))

# %%
artviewsub=[]
for i in tqdm_notebook(list(artview['pid'])):
    try:
        artviewsub.append(cat[cat['id'].isin([i])].reset_index()['subChannelTitle'][0])
    except:
        artviewsub.append(None)
artview['subChannelTitle']=artviewsub
# Out:
# HBox(children=(IntProgress(value=0, max=348), HTML(value='')))

# %%
artviewkey=[]
for i in tqdm_notebook(list(artview['pid'])):
    try:
        artviewkey.append(cat[cat['id'].isin([i])].reset_index()['keyword'][0])
    except:
        artviewkey.append(None)
artview['keyword']=artviewkey
# Out:
# HBox(children=(IntProgress(value=0, max=348), HTML(value='')))

# %%
artview.drop(['pid','15~45','45~60','60~85','總瀏覽數','masterChannelTitle','subChannelTitle','keyword'],axis=1)
# Out:
#       45~60比例                                        title
# 0    0.663662                             【天下全閱讀】暢讀天下的9種方法
# 1    0.561922                          蔡淇華：母親的魔法　讓哥哥２度戰勝癌症
# 2    0.551402                                聰明慢老，坐而憂不如起而行
# 3    0.546798              平均４個大學生，就有１人休退學　葉丙成：人生不是贏在十八歲就好
# 4    0.541741                 每3個失智者中，有1個其實可以不發病！神經科醫師8招護腦
# 5    0.538726                          長榮罷工為何進入延長賽？接下來會怎樣？
# 6    0.527183                       台科大校長廖慶榮：是誰在阻礙台灣高教競爭力？
# 7    0.512621                           掌握3原則、2時段　啟動身體回春機制
# 8    0.504624               【聰明慢老實用指南】預防失能失智，但願我們都能健康到最後一刻
# 9    0.503096               張小燕不退休教我的事：持之以恆的興趣，才是你可以捧牢的鐵飯碗
# 10   0.498691                     天下財經週報：韓流發威了？來台旅客人數雙位數成長
# 11   0.498191                     韓國瑜從失業到凱道萬人擁戴　貴人是張榮味、傅崐萁
# 12   0.494905                罹癌、淡出歌壇、照顧父母20年　方季惟：練習如何為自己而活
# 13   0.494845                           這家養老院　憑什麼成為台灣第一品牌？
# 14   0.493920              吳淡如：我曾以為好文憑是世上最好資源，這樣就不用一直證明我不笨
# 15   0.493124                     稀土是什麼？為何可能是中國在貿易戰中的王牌槓桿？
# 16   0.487476              老公說我們在印度是住高級住宅區，直到有一群牛悠悠走過.....
# 17   0.485294                     東京攝影作家：我能做的，就是告訴全世界台灣的美！
# 18   0.483389                               民進黨初選　蔡英文大勝賴清德
# 19   0.480226                 「還好我有得癌症！」葉金川活回學生時代：玩到人生最後一天
# 20   0.478799                丘美珍：明星高中畢業30年後，才發現人生的真相……原來如此
# 21   0.475822  「最後一刻，我讓父母急救插管......」諮商心理師艾彼：放下悔恨，有時我們的選擇不多
# 22   0.475694                      張曼娟：自私是一種美德，每人都要學會拒絕的勇氣
# 23   0.475434                          葉丙成：不論推甄或指考　對窮孩子都不利
# 24   0.472306                爬樓梯、深蹲傷膝蓋？醫師告訴你怎麼動才不會提早去復健科報到
# 25   0.469012                     等退休再談夢想，你已經老了！人生不是只有工作而已
# 26   0.467072                        從驚嚇變驚喜！一個家庭主婦的印度不思議生活
# 27   0.465241                      中國三線城市長出台灣半導體聚落，韓冰是幕後推手
# 28   0.463816                                中美貿易戰會不會長期持續？
# 29   0.463511                            華為可以靠自己的作業系統活下去嗎？
# ..        ...                                          ...
# 318  0.294040                                ８個小動作　說明了你整個人
# 319  0.290216                                  張忠謀　還給員工兩小時
# 320  0.290164                享受歲月　宋慧喬：我變老了，但我反而很好奇自己變老的樣子！
# 321  0.287889                             穿著外出服，不該坐上床？真的嗎？
# 322  0.285061                       蔡康永：「做自己」跟「沒禮貌」常常是一線之間
# 323  0.281553                            什麼樣的工作不值得做？歐普拉告訴你
# 324  0.280645                       PTT原始資料全揭露！「韓流」怎麼造出來的？
# 325  0.278922                      催婚、逼婚...樣樣來，人生並不是非結婚不可！
# 326  0.278777                      陶晶瑩：那段沒有朋友、沒有人生，只有工作的日子
# 327  0.278094                                    你該戒糖的9個徵兆
# 328  0.276730                                是的，我們註定跟錯的人結婚
# 329  0.272904                  如果《與惡》應思聰是你哥哥？一個思覺失調患者家屬的自白
# 330  0.271429                               心好累，別忘了回過頭照顧自己
# 331  0.268775                        一個人是不是好主管　寄個e-mail就知道
# 332  0.267045                           ３大常被嫌棄特質　卻是聰明人的共通點
# 333  0.263850                     串流時代下的金曲30：歌手都不認識？你不是老了！
# 334  0.263798                  走過乏人問津的32歲　吳慷仁：珍惜瓶頸，代表看得到未來
# 335  0.258824                         「你看起來很累」　高EQ者不會說的８句話
# 336  0.256724                       日本超商招牌第一個字　為什麼到了５月就不亮？
# 337  0.250909                             年輕人為何很難管理？四個原來如此
# 338  0.250883                                ４強烈跡象　好員工即將走人
# 339  0.249635                   等了27年改編的《 阿拉丁》，為何是迪士尼致歉之作？
# 340  0.248954                      如何擺脫焦慮？親愛的，你最需要的是「原諒自己」
# 341  0.244094                 不是故意不合作 ！御姊愛：學習尊重你的「內向型人格」伴侶
# 342  0.243902                        員工思考離職很久了　為什麼老闆一直不知道？
# 343  0.242481                    「可以結婚了！」　台灣成為亞洲第一同婚合法化的國家
# 344  0.238019                             科學證實　不出舒適圈，你很難學習
# 345  0.229508                        蘋果公司內規  別讓庫克問第3次「為什麼」
# 346  0.228037                    「沒有人該為你的成長負責」 寫一封信給工作疲憊的你
# 347  0.212308                                 你適合當主管的10個跡象
#
# [348 rows x 2 columns]

# %%
artview.to_csv(r'C:\Users\wells\OneDrive\Desktop\14~60view.csv',encoding='utf_8_sig')
